# %%
# comparison operator

a = 6
print(a == 6);

# inequality operator
# >, <, >=, <=, !=


# logic operators (compound statements)
# not (!), or, and


# arithmetic operator
# +, -, *, /, %, //
# https://www.w3schools.com/python/gloss_python_arithmetic_operators.asp

# Assignment operator
# =, +=, -=, *=, /=, %=, //=, **=, &=, |=, ^=, >>=, <<=
# https://www.w3schools.com/python/gloss_python_assignment_operators.asp



# membership operator
# in, not in
# Out:
# True
