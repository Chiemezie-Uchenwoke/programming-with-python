# %%
person = {"name": "ade"}

if "name" in person:
    print(f"The workers name is: {person["name"]} ")

if len(person["name"]) >= 3:
    print("Name is accepted")
# Out:
# The workers name is: ade
# Name is accepted

# %%
def get_dict_properties(dict):
    return dict.keys()

workers_keys = get_dict_properties({"name": "John Doe", "age": 33, ""})
