# %%
# if statements

person = {"name": "ade"}

if ("name" in person):
    print(f"The workers name is: {person["name"]} ")

if (len(person["name"]) >= 3):
    print("Name is accepted")


# If else statement
age = 19
if (age < 18): 
    print("Not qualified")
else: 
    print("You are qualified")


# elif statement
if (age < 18):
    print("Not qualified!")
elif (age == 18):
    print("You are qualified, but under certain conditions!")
else:
    print("Qualified!")
# Out:
# The workers name is: ade
# Name is accepted
# You are qualified
# Qualified!
