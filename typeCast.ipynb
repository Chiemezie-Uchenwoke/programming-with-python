# %%
print(int('4'))
# Out:
# 4

# %%
print(int(4.233))
# Out:
# 4
# 4

# %%
print(float(4))
# Out:
# 4.0

# %%
print(str(45))
# Out:
# 45

# %%
print(bool("45"))
# Out:
# True

# %%
# Data Types in python
# int: Integers
# float
# str: Strings
# bool: True or False
# range: range(1, 10)
# None: NoneType
# tuples (tuple): ()
# lists (list): []
# dictionaries (dict): {}
# set: {1, 2, 3}
