# %%
def sayHello(user):
    print(f"Hello {user}, welcome")

sayHello("Chiemezie")
sayHello("John Doe")
# Out:
# Hello Chiemezie, welcome
# Hello John Doe, welcome

# %%
productPrice = 20000
discount = 0.1
discountPrice = productPrice * discount
print(discountPrice)
# Out:
# 2000.0

# %%
def addTwoNumbers(x, y):
    return x + y

result = addTwoNumbers(3, 4)
print(result)

def doubleNum(num):
    print(f"The result is: {num * 2}")

doubleNum(addTwoNumbers(3, 4))
# Out:
# 7
# The result is: 14

# %%
def get_dict_properties(dict):
    return dict.keys()

workers_keys = get_dict_properties({"name": "John Doe", "age": 33, "role": "Senior software engineer", "is active": True})
print(workers_keys)
# Out:
# dict_keys(['name', 'age', 'role', 'is active'])
